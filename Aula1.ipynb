# %%
import pyautogui
import time
import pyperclip

pyautogui.PAUSE = 1

# %%
# Abrir um navegador de internet (usando teclado)
pyautogui.press('winleft')
pyautogui.write('chrome')
pyautogui.press('enter')
pyautogui.hotkey('ctrl','t')

# %%
# Copiar o link do Google Drive onde está nossa base de dados (usando teclado)
pyperclip.copy('https://drive.google.com/drive/folders/149xknr9JvrlEnhNWO49zPcw0PW5icxga')

# %%
# Entrar no Google Drive onde está nossa base de dados (usando teclado)
pyautogui.hotkey('ctrl','v')
pyautogui.press('enter')
time.sleep(5)

# %%
# Abrir pasta Aula 1 do Google Drive (usando mouse)
pyautogui.click(x=430, y=267, clicks=2)
time.sleep(3)

# %%
# Baixar planilha "Vendas - Dez.xlsx" (usando mouse)
pyautogui.click(x=430, y=267)
pyautogui.click(x=1161, y=160)
pyautogui.click(x=909, y=595)
time.sleep(5)

# %%
# Importando a base de dados
import pandas as pd
tabela = pd.read_excel(r"C:\Users\gabri\Downloads\Vendas - Dez.xlsx")
display(tabela)
# Out:
#       Código Venda       Data                     ID Loja           Produto  \
# 0            65014 2019-12-01            Shopping Morumbi    Sunga Listrado
# 1            65014 2019-12-01            Shopping Morumbi   Casaco Listrado
# 2            65016 2019-12-01           Iguatemi Campinas   Sapato Listrado
# 3            65016 2019-12-01           Iguatemi Campinas            Casaco
# 4            65017 2019-12-01          Shopping SP Market        Gorro Liso
# ...            ...        ...                         ...               ...
# 7084         69996 2019-12-26  Center Shopping Uberlândia    Short Listrado
# 7085         69996 2019-12-26  Center Shopping Uberlândia           Mochila
# 7086         69996 2019-12-26  Center Shopping Uberlândia  Pulseira Estampa
# 7087         69997 2019-12-26           Ribeirão Shopping   Camisa Listrado
# 7088         69997 2019-12-26           Ribeirão Shopping       Short Linho
#
#       Quantidade  Valor Unitário  Valor Final
# ...

# %%
# Calculando o Faturamento e a Quantidade de Produtos
faturamento = tabela['Valor Final'].sum()
qtde_prod = tabela['Quantidade'].sum()

# %%
# Criando um relatório via e-mail
#pyautogui.press('winleft')
#pyautogui.write('chrome')
#pyautogui.press('enter')
#pyautogui.hotkey('winleft','up')
pyautogui.hotkey('ctrl','t')

pyperclip.copy('https://outlook.live.com/mail/')
pyautogui.hotkey('ctrl','v')
pyautogui.press('enter')
time.sleep(5)

pyautogui.press('n') #Escrever novo e-mail
time.sleep(2)

pyperclip.copy("fulano@detal.com")
pyautogui.hotkey('ctrl','v')
pyautogui.press('tab')
pyperclip.copy("Relatório de vendas")
pyautogui.hotkey('ctrl','v')
pyautogui.press('tab')
email = f"""Prezado Rafael, boa tarde!
O faturamento de ontem foi de: R${faturamento:,.2f}
Foram vendidos {qtde_prod:,} produtos.

Este relatório foi gerado automaticamente com o Python :D

Abraços"""
pyperclip.copy(email)
pyautogui.hotkey('ctrl','v')
pyautogui.click(x=700, y=139)
time.sleep(15)
pyautogui.hotkey('alt','f4')

# %%
time.sleep(5)
pyautogui.position()
# Out:
# Point(x=767, y=25)
